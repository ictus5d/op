# %% [markdown]
# Qu'est le temps et la lumière ?

# %%
# %display latex

# %%
var("t c f v w L C")
t_0=t==1/f;show(t_0);f_0=f==1/t;show(f_0)
c_0=c==f*t;show(c)
# Out:
# t == (1/f)
# f == (1/t)
# c

# %%
var("w L C")
w_0=w==1/sqrt(L*C);show(w_0)
# Out:
# w == 1/sqrt(C*L)

# %%
var("v epsilon mu ")
v_0=v==1/sqrt(mu*epsilon);show(v_0)
# Out:
# v == 1/sqrt(epsilon*mu)

# %%
w=1/sqrt(0.1*1);w
# Out:
# 3.16227766016838

# %%
w/(2*n(pi))
# Out:
# 0.503292121044870

# %%
f=1/(2*n(pi));vc=f*3;vc
# Out:
# 0.477464829275686

# %%
1/1.047/2
# Out:
# 0.477554918815664

# %%
299792458/314159265.3/2
# Out:
# 0.477134516013270

# %% [markdown]
# Onde perturbation d'un milieu sans transport de matière, avec toutefois un transport d'énergie.

# %%
y(x,t)=-0.3/(1+(x+7-2*t)^4)+0.3/(1+(x-7+2*t)^4)
superposition=animate([y(x,k*0.05) for k in range(0,140)],xmin=-10,xmax=10,ymin=-0.3,ymax=0.3,figsize=[8,4])

# %%
superposition.show(delay=0.1)
# Out:
# Animation with 140 frames

# %%
var('t omega Q f')
y=function('y')(t)
eq=diff(y,t,2)+omega*diff(y,t)/Q+omega^2*y==omega^2*cos(2*pi*f*t);eq
# Out:
# omega^2*y(t) + omega*diff(y(t), t)/Q + diff(y(t), t, t) == omega^2*cos(2*pi*f*t)

# %%
var("x,y,x1,y1,x2,y2,x3,y3,r1,r2,r3,m1,m2,m3,g")
r1 = sqrt((x-x1)^2+(y-y1)^2)
r2 = sqrt((x-x2)^2+(y-y2)^2)
r3 = sqrt((x-x3)^2+(y-y3)^2)
U = g*(m1/r1+m2/r2+m3/r3)
dU = U.gradient()
show("potentiel = ", U)
show("gradient = ", dU)
# Out:
# 'potentiel = ' g*(m1/sqrt((x - x1)^2 + (y - y1)^2) + m2/sqrt((x - x2)^2 + (y - y2)^2) + m3/sqrt((x - x3)^2 + (y - y3)^2))
# 'gradient = ' (m1/sqrt((x - x1)^2 + (y - y1)^2) + m2/sqrt((x - x2)^2 + (y - y2)^2) + m3/sqrt((x - x3)^2 + (y - y3)^2), g/sqrt((x - x1)^2 + (y - y1)^2), g/sqrt((x - x2)^2 + (y - y2)^2), g/sqrt((x - x3)^2 + (y - y3)^2), -g*(m1*(x - x1)/((x - x1)^2 + (y - y1)^2)^(3/2) + m2*(x - x2)/((x - x2)^2 + (y - y2)^2)^(3/2) + m3*(x - x3)/((x - x3)^2 + (y - y3)^2)^(3/2)), g*m1*(x - x1)/((x - x1)^2 + (y - y1)^2)^(3/2), g*m2*(x - x2)/((x - x2)^2 + (y - y2)^2)^(3/2), g*m3*(x - x3)/((x - x3)^2 + (y - y3)^2)^(3/2), -g*(m1*(y - y1)/((x - x1)^2 + (y - y1)^2)^(3/2) + m2*(y - y2)/((x - x2)^2 + (y - y2)^2)^(3/2) + m3*(y - y3)/((x - x3)^2 + (y - y3)^2)^(3/2)), g*m1*(y - y1)/((x - x1)^2 + (y - y1)^2)^(3/2), g*m2*(y - y2)/((x - x2)^2 + (y - y2)^2)^(3/2), g*m3*(y - y3)/((x - x3)^2 + (y - y3)^2)^(3/2))

# %%
Un = U(g=1,m=1,m1=12,x1=-5,y1=0,m2=9,x2=3,y2=0,m3=6,x3=0,y3=8)
dUn = Un.gradient()
show(Un) ; show(dUn)
# Out:
# 12/sqrt((x + 5)^2 + y^2) + 9/sqrt((x - 3)^2 + y^2) + 6/sqrt(x^2 + (y - 8)^2)
# (-12*(x + 5)/((x + 5)^2 + y^2)^(3/2) - 9*(x - 3)/((x - 3)^2 + y^2)^(3/2) - 6*x/(x^2 + (y - 8)^2)^(3/2), -6*(y - 8)/(x^2 + (y - 8)^2)^(3/2) - 12*y/((x + 5)^2 + y^2)^(3/2) - 9*y/((x - 3)^2 + y^2)^(3/2))

# %%
G1 = implicit_plot(dUn[0]==0,
(x,-6,3),(y,-1,9),cmap="Reds_r")
G2 = implicit_plot(dUn[1]==0,(x,-6,3),
(y,-1,9),cmap="Blues_r")
show(G1+G2, aspect_ratio=1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot3d(Un,(x,-4,2),(y,-1,7))
# Out:
# Graphics3d Object
